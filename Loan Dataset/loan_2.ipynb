# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Loan 2.csv')

# %%
df.isnull().sum()
# Out:
# Customer ID                       0
# Name                              0
# Gender                           53
# Age                               0
# Income (USD)                   4576
# Income Stability               1683
# Profession                        0
# Type of Employment             7270
# Location                          0
# Loan Amount Request (USD)         0
# Current Loan Expenses (USD)     172
# Expense Type 1                    0
# Expense Type 2                    0
# Dependents                     2493
# Credit Score                   1703
# No. of Defaults                   0
# Has Active Credit Card         1566
# Property ID                       0
# Property Age                   4850
# Property Type                     0
# Property Location               356
# Co-Applicant                      0
# Property Price                    0
# Loan Sanction Amount (USD)      340
# dtype: int64

# %%
df['Profession'].unique()
# Out:
# array(['Working', 'Pensioner', 'State servant', 'Commercial associate',
#        'Unemployed', 'Student', 'Businessman', 'Maternity leave'],
#       dtype=object)

# %%
df['Income Stability'].unique()
# Out:
# array(['Low', 'High', nan], dtype=object)

# %%
conditions=[
    (df['Income Stability'].notnull()),
    (df['Income Stability'].isnull())&(df['Profession']=='Commercial associate'),#Low
    (df['Income Stability'].isnull())&(df['Profession']=='Working'),#Low
    (df['Income Stability'].isnull())&(df['Profession']=='Pensioner'),#High
    (df['Income Stability'].isnull())&(df['Profession']=='State servant'),#Low
    (df['Income Stability'].isnull())&(df['Profession']=='Unemployed'),#Low
    (df['Income Stability'].isnull())&(df['Profession']=='Maternity leave'),#Low
    (df['Income Stability'].isnull())&(df['Profession']=='Student'),#Low
    (df['Income Stability'].isnull())&(df['Profession']=='Businessman')#Low    
]

values=[
    df['Income Stability'],
    'Low',
    'Low',
    'High',
    'Low',
    'Low',
    'Low',
    'Low',
    'High'
]
df['Income Stability'] = np.select(conditions, values, default='Unknown')
df['Income Stability'].isnull().sum()
# Out:
# 0

# %%
df['Gender'].fillna(df['Gender'].mode()[0], inplace=True)
df.isnull().sum()
# Out:
# Customer ID                       0
# Name                              0
# Gender                            0
# Age                               0
# Income (USD)                   4576
# Income Stability                  0
# Profession                        0
# Type of Employment             7270
# Location                          0
# Loan Amount Request (USD)         0
# Current Loan Expenses (USD)     172
# Expense Type 1                    0
# Expense Type 2                    0
# Dependents                     2493
# Credit Score                   1703
# No. of Defaults                   0
# Has Active Credit Card         1566
# Property ID                       0
# Property Age                   4850
# Property Type                     0
# Property Location               356
# Co-Applicant                      0
# Property Price                    0
# Loan Sanction Amount (USD)      340
# dtype: int64

# %%
sns.heatmap(df.isnull(), cbar=False)
plt.show()

# %%
df['Income (USD)'].fillna(df['Income (USD)'].mean(), inplace=True)
df.isnull().sum()
# Out:
# Customer ID                       0
# Name                              0
# Gender                            0
# Age                               0
# Income (USD)                      0
# Income Stability                  0
# Profession                        0
# Type of Employment             7270
# Location                          0
# Loan Amount Request (USD)         0
# Current Loan Expenses (USD)     172
# Expense Type 1                    0
# Expense Type 2                    0
# Dependents                     2493
# Credit Score                   1703
# No. of Defaults                   0
# Has Active Credit Card         1566
# Property ID                       0
# Property Age                   4850
# Property Type                     0
# Property Location               356
# Co-Applicant                      0
# Property Price                    0
# Loan Sanction Amount (USD)      340
# dtype: int64

# %%
df['Dependents'].unique()
# Out:
# array([ 3.,  1.,  2., nan,  4.,  5.,  8.,  6.,  7., 10., 14.])

# %%
mode=df['Dependents'].mode()
print(mode)
# Out:
# 0    2.0
# Name: Dependents, dtype: float64

# %%
df['Dependents'].fillna(df['Dependents'].mode()[0],inplace=True)
df.isnull().sum()
# Out:
# Customer ID                       0
# Name                              0
# Gender                            0
# Age                               0
# Income (USD)                      0
# Income Stability                  0
# Profession                        0
# Type of Employment             7270
# Location                          0
# Loan Amount Request (USD)         0
# Current Loan Expenses (USD)     172
# Expense Type 1                    0
# Expense Type 2                    0
# Dependents                        0
# Credit Score                   1703
# No. of Defaults                   0
# Has Active Credit Card         1566
# Property ID                       0
# Property Age                   4850
# Property Type                     0
# Property Location               356
# Co-Applicant                      0
# Property Price                    0
# Loan Sanction Amount (USD)      340
# dtype: int64

# %%
mean=df['Credit Score'].mean()
median=df['Credit Score'].median()
print(mean,median)
# Out:
# 739.8853811358094 739.82

# %%
df['Credit Score'].fillna(df['Credit Score'].mean(), inplace=True)
df.isnull().sum()
# Out:
# Customer ID                       0
# Name                              0
# Gender                            0
# Age                               0
# Income (USD)                      0
# Income Stability                  0
# Profession                        0
# Type of Employment             7270
# Location                          0
# Loan Amount Request (USD)         0
# Current Loan Expenses (USD)     172
# Expense Type 1                    0
# Expense Type 2                    0
# Dependents                        0
# Credit Score                      0
# No. of Defaults                   0
# Has Active Credit Card         1566
# Property ID                       0
# Property Age                   4850
# Property Type                     0
# Property Location               356
# Co-Applicant                      0
# Property Price                    0
# Loan Sanction Amount (USD)      340
# dtype: int64

# %%
mode=df['Has Active Credit Card'].mode()
print(mode)
# Out:
# 0    Active
# Name: Has Active Credit Card, dtype: object

# %%
df['Has Active Credit Card'].fillna(df['Has Active Credit Card'].mode()[0], inplace=True)
df.isnull().sum()
# Out:
# Customer ID                       0
# Name                              0
# Gender                            0
# Age                               0
# Income (USD)                      0
# Income Stability                  0
# Profession                        0
# Type of Employment             7270
# Location                          0
# Loan Amount Request (USD)         0
# Current Loan Expenses (USD)     172
# Expense Type 1                    0
# Expense Type 2                    0
# Dependents                        0
# Credit Score                      0
# No. of Defaults                   0
# Has Active Credit Card            0
# Property ID                       0
# Property Age                   4850
# Property Type                     0
# Property Location               356
# Co-Applicant                      0
# Property Price                    0
# Loan Sanction Amount (USD)      340
# dtype: int64

# %%
print(df['Property Age'].head())
# Out:
# 0    1933.05
# 1    4952.91
# 2     988.19
# 3        NaN
# 4    2614.77
# Name: Property Age, dtype: float64

# %%
df.isnull().sum()
# Out:
# Customer ID                       0
# Name                              0
# Gender                            0
# Age                               0
# Income (USD)                      0
# Income Stability                  0
# Profession                        0
# Type of Employment             7270
# Location                          0
# Loan Amount Request (USD)         0
# Current Loan Expenses (USD)     172
# Expense Type 1                    0
# Expense Type 2                    0
# Dependents                        0
# Credit Score                      0
# No. of Defaults                   0
# Has Active Credit Card            0
# Property ID                       0
# Property Age                   4850
# Property Type                     0
# Property Location               356
# Co-Applicant                      0
# Property Price                    0
# Loan Sanction Amount (USD)      340
# dtype: int64

# %%
m=df['Property Age'].mode()
print(m)
# Out:
# 0    1608.43
# 1    2415.70
# Name: Property Age, dtype: float64

# %%
df['Property Age'].fillna(df['Property Age'].mode()[0], inplace=True)
df['Property Location'].fillna(df['Property Location'].mode()[0],inplace=True)

# %%
df.isnull().sum()
# Out:
# Customer ID                       0
# Name                              0
# Gender                            0
# Age                               0
# Income (USD)                      0
# Income Stability                  0
# Profession                        0
# Type of Employment             7270
# Location                          0
# Loan Amount Request (USD)         0
# Current Loan Expenses (USD)     172
# Expense Type 1                    0
# Expense Type 2                    0
# Dependents                        0
# Credit Score                      0
# No. of Defaults                   0
# Has Active Credit Card            0
# Property ID                       0
# Property Age                      0
# Property Type                     0
# Property Location                 0
# Co-Applicant                      0
# Property Price                    0
# Loan Sanction Amount (USD)      340
# dtype: int64

# %%
data = {
    'Customer ID': ['C-36995'],
    'Name': ['Frederica Shealy'],
    'Gender': ['F'],
    'Age': [56],
    'Income (USD)': [1933.05],
    'Income Stability': ['Low'],
    'Profession': ['Working'],
    'Type of Employment': ['Sales staff'],
    'Location': ['Semi-Urban'],
    'Loan Amount Request (USD)': [72809.58],
    'Current Loan Expenses (USD)': [241.08],
    'Expense Type 1': ['N'],
    'Expense Type 2': ['N'],
    'Dependents': [3],
    'Credit Score': [809.44],
    'No. of Defaults': [0],
    'Has Active Credit Card': [''],
    'Property ID': [746],
    'Property Age': ['16 April 1905'],
    'Property Type': [4],
    'Property Location': ['Rural'],
    'Co-Applicant': [1],
    'Property Price': [119933.46],
    'Loan Sanction Amount (USD)': [54607.18]
}

numerical_columns = df.select_dtypes(include=['number']).columns.tolist()
categorical_columns = df.select_dtypes(include=['object', 'category']).columns.tolist()

print("\nCategorical Columns:")
print(categorical_columns)
# Out:
# Categorical Columns:
# ['Customer ID', 'Name', 'Gender', 'Income Stability', 'Profession', 'Type of Employment', 'Location', 'Expense Type 1', 'Expense Type 2', 'Has Active Credit Card', 'Property Location']

# %%
correlation_matrix = df[numerical_columns].corr()
print(correlation_matrix)
# Out:
#                                   Age  Income (USD)  \
# Age                          1.000000     -0.009392
# Income (USD)                -0.009392      1.000000
# Loan Amount Request (USD)   -0.010450      0.046155
# Current Loan Expenses (USD) -0.023684      0.050211
# Dependents                  -0.079574      0.004799
# Credit Score                 0.125900      0.011922
# No. of Defaults              0.003573     -0.001967
# Property ID                 -0.012358     -0.007493
# Property Age                -0.009718      0.999237
# Property Type                0.002196      0.008960
# Co-Applicant                 0.000632      0.000404
# Property Price              -0.009819      0.046484
# Loan Sanction Amount (USD)   0.008112      0.034997
#
#                              Loan Amount Request (USD)  \
# Age                                          -0.010450
# Income (USD)                                  0.046155
# Loan Amount Request (USD)                     1.000000
# Current Loan Expenses (USD)                   0.682248
# Dependents                                    0.039394
# Credit Score                                  0.173329
# No. of Defaults                               0.000088
# Property ID                                  -0.008426
# Property Age                                  0.045192
# Property Type                                 0.003802
# Co-Applicant                                  0.001864
# Property Price                                0.948350
# Loan Sanction Amount (USD)                    0.726408
#
#                              Current Loan Expenses (USD)  Dependents  \
# Age                                            -0.023684   -0.079574
# Income (USD)                                    0.050211    0.004799
# Loan Amount Request (USD)                       0.682248    0.039394
# Current Loan Expenses (USD)                     1.000000    0.043807
# Dependents                                      0.043807    1.000000
# Credit Score                                    0.111776   -0.083630
# No. of Defaults                                 0.002767    0.008420
# Property ID                                    -0.014519    0.001881
# Property Age                                    0.049488    0.004853
# Property Type                                   0.014812   -0.008387
# Co-Applicant                                    0.002130    0.003115
# Property Price                                  0.648636    0.035983
# Loan Sanction Amount (USD)                      0.485070    0.004788
#
#                              Credit Score  No. of Defaults  Property ID  \
# Age                              0.125900         0.003573    -0.012358
# Income (USD)                     0.011922        -0.001967    -0.007493
# Loan Amount Request (USD)        0.173329         0.000088    -0.008426
# Current Loan Expenses (USD)      0.111776         0.002767    -0.014519
# Dependents                      -0.083630         0.008420     0.001881
# Credit Score                     1.000000         0.006453    -0.005888
# No. of Defaults                  0.006453         1.000000    -0.001282
# Property ID                     -0.005888        -0.001282     1.000000
# Property Age                     0.011659        -0.002106    -0.007304
# Property Type                    0.008849         0.000477     0.008658
# Co-Applicant                     0.009203        -0.008191     0.008151
# Property Price                   0.166004         0.001718    -0.011890
# Loan Sanction Amount (USD)       0.359709        -0.004330    -0.009751
#
#                              Property Age  Property Type  Co-Applicant  \
# Age                             -0.009718       0.002196      0.000632
# Income (USD)                     0.999237       0.008960      0.000404
# Loan Amount Request (USD)        0.045192       0.003802      0.001864
# Current Loan Expenses (USD)      0.049488       0.014812      0.002130
# Dependents                       0.004853      -0.008387      0.003115
# Credit Score                     0.011659       0.008849      0.009203
# No. of Defaults                 -0.002106       0.000477     -0.008191
# Property ID                     -0.007304       0.008658      0.008151
# Property Age                     1.000000       0.008957      0.001090
# Property Type                    0.008957       1.000000     -0.001105
# Co-Applicant                     0.001090      -0.001105      1.000000
# Property Price                   0.045765       0.003279      0.005792
# Loan Sanction Amount (USD)       0.031361       0.001984     -0.006945
#
#                              Property Price  Loan Sanction Amount (USD)
# Age                               -0.009819                    0.008112
# Income (USD)                       0.046484                    0.034997
# Loan Amount Request (USD)          0.948350                    0.726408
# Current Loan Expenses (USD)        0.648636                    0.485070
# Dependents                         0.035983                    0.004788
# Credit Score                       0.166004                    0.359709
# No. of Defaults                    0.001718                   -0.004330
# Property ID                       -0.011890                   -0.009751
# Property Age                       0.045765                    0.031361
# Property Type                      0.003279                    0.001984
# Co-Applicant                       0.005792                   -0.006945
# Property Price                     1.000000                    0.687181
# Loan Sanction Amount (USD)         0.687181                    1.000000

# %%
df['Loan Sanction Amount (USD)'].min()
# Out:
# -999.0

# %%
Loan_Sanction_Amount_core=correlation_matrix['Loan Sanction Amount (USD)'].sort_values(ascending=False)
print(Loan_Sanction_Amount_core)
# Out:
# Loan Sanction Amount (USD)     1.000000
# Loan Amount Request (USD)      0.726408
# Property Price                 0.687181
# Current Loan Expenses (USD)    0.485070
# Credit Score                   0.359709
# Income (USD)                   0.034997
# Property Age                   0.031361
# Age                            0.008112
# Dependents                     0.004788
# Property Type                  0.001984
# No. of Defaults               -0.004330
# Co-Applicant                  -0.006945
# Property ID                   -0.009751
# Name: Loan Sanction Amount (USD), dtype: float64

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Matrix')
plt.show()

# %%
#df['Type of Employment'].unique().value_counts()

# %%
df['Profession'].unique()
# Out:
# array(['Working', 'Pensioner', 'State servant', 'Commercial associate',
#        'Unemployed', 'Student', 'Businessman', 'Maternity leave'],
#       dtype=object)

# %%
unique_values = df['Type of Employment'].unique()
value_counts = df['Type of Employment'].value_counts()

unique_values, value_counts
# Out:
# (array(['Sales staff', nan, 'High skill tech staff', 'Secretaries',
#         'Laborers', 'Managers', 'Cooking staff', 'Core staff', 'Drivers',
#         'Realty agents', 'Security staff', 'Accountants',
#         'Private service staff', 'Waiters/barmen staff', 'Medicine staff',
#         'Cleaning staff', 'Low-skill Laborers', 'HR staff', 'IT staff'],
#        dtype=object),
#  Type of Employment
#  Laborers                 5578
#  Sales staff              3736
#  Core staff               3230
#  Managers                 2495
#  Drivers                  1606
#  Accountants              1379
#  High skill tech staff    1307
#  Medicine staff            864
#  Security staff            579
#  Cooking staff             566
#  Private service staff     342
#  Cleaning staff            341
#  Low-skill Laborers        162
#  Secretaries               161
#  Waiters/barmen staff      149
#  Realty agents              86
#  IT staff                   77
#  HR staff                   72
#  Name: count, dtype: int64)

# %%
df['Property Location'].value_counts()
# Out:
# Property Location
# Semi-Urban    10743
# Rural         10041
# Urban          9216
# Name: count, dtype: int64

# %%
df['Property Location'].fillna(df['Property Location'].mode()[0], inplace=True)

# %%
mode=df['Type of Employment'].mode()
print(mode)
# Out:
# 0    Laborers
# Name: Type of Employment, dtype: object

# %%
df['Type of Employment'].fillna(df['Type of Employment'].mode()[0],inplace=True)

# %%
mean=df['Loan Sanction Amount (USD)'].mean()
median=df['Loan Sanction Amount (USD)'].median()
print(mean,median)
# Out:
# 47649.342208361435 35209.395000000004

# %%
df['Loan Sanction Amount (USD)'].fillna(df['Loan Sanction Amount (USD)'].mean(),inplace=True)

# %%
plt.hist(df['Loan Sanction Amount (USD)'])
# Out:
# (array([1.7076e+04, 8.2840e+03, 3.2640e+03, 1.0100e+03, 3.0200e+02,
#         5.4000e+01, 8.0000e+00, 0.0000e+00, 1.0000e+00, 1.0000e+00]),
#  array([  -999.   ,  47291.632,  95582.264, 143872.896, 192163.528,
#         240454.16 , 288744.792, 337035.424, 385326.056, 433616.688,
#         481907.32 ]),
#  <BarContainer object of 10 artists>)

# %%
loan_sanction_amount = df['Loan Sanction Amount (USD)']
Q1= loan_sanction_amount.quantile(0.25)
Q3 = loan_sanction_amount.quantile(0.75)
IQR= Q3- Q1
lower_bound= Q1- 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
loan_sanction_outliers = df[
    (loan_sanction_amount < lower_bound) |(loan_sanction_amount > upper_bound)
    ]
odf=loan_sanction_outliers[['Customer ID', 'Name', 'Loan Sanction Amount (USD)']]
ndf = df[
    (loan_sanction_amount >= lower_bound) & (loan_sanction_amount <= upper_bound)]
dfclear=ndf[['Customer ID', 'Name', 'Loan Sanction Amount (USD)']]

# %%
odf.to_csv('loan_sanction_outliers.csv', index=False)

# %%
plt.figure(figsize=(10, 6))
plt.hist(data['Loan Sanction Amount (USD)'], bins=30, alpha=0.7, label='Loan Sanction Amount')
plt.legend()
plt.show()

# %%
dfclear['Loan Sanction Amount (USD)'].median()
# Out:
# 34929.45

# %%
df=df.fillna({'Loan Sanction Amount (USD)':34198.14})

# %%
median_value = df['Loan Sanction Amount (USD)'].median()
df.loc[
    (loan_sanction_amount < lower_bound) | (loan_sanction_amount > upper_bound),
    'Loan Sanction Amount (USD)'
] = median_value
df['Loan Sanction Amount (USD)'].min()
# Out:
# -999.0

# %%
plt.hist(df['Loan Sanction Amount (USD)'])
# Out:
# (array([9774., 5219., 4565., 3295., 2499., 1742., 1261.,  827.,  491.,
#          327.]),
#  array([  -999.   ,  17510.005,  36019.01 ,  54528.015,  73037.02 ,
#          91546.025, 110055.03 , 128564.035, 147073.04 , 165582.045,
#         184091.05 ]),
#  <BarContainer object of 10 artists>)

# %%
df.isnull().sum()
# Out:
# Customer ID                      0
# Name                             0
# Gender                           0
# Age                              0
# Income (USD)                     0
# Income Stability                 0
# Profession                       0
# Type of Employment               0
# Location                         0
# Loan Amount Request (USD)        0
# Current Loan Expenses (USD)    172
# Expense Type 1                   0
# Expense Type 2                   0
# Dependents                       0
# Credit Score                     0
# No. of Defaults                  0
# Has Active Credit Card           0
# Property ID                      0
# Property Age                     0
# Property Type                    0
# Property Location                0
# Co-Applicant                     0
# Property Price                   0
# Loan Sanction Amount (USD)       0
# dtype: int64

# %%
df['Current Loan Expenses (USD)'].fillna(df['Current Loan Expenses (USD)'].mean(), inplace=True)

# %%
df.isnull().sum()
# Out:
# Customer ID                    0
# Name                           0
# Gender                         0
# Age                            0
# Income (USD)                   0
# Income Stability               0
# Profession                     0
# Type of Employment             0
# Location                       0
# Loan Amount Request (USD)      0
# Current Loan Expenses (USD)    0
# Expense Type 1                 0
# Expense Type 2                 0
# Dependents                     0
# Credit Score                   0
# No. of Defaults                0
# Has Active Credit Card         0
# Property ID                    0
# Property Age                   0
# Property Type                  0
# Property Location              0
# Co-Applicant                   0
# Property Price                 0
# Loan Sanction Amount (USD)     0
# dtype: int64

# %%
df.to_csv('finalloan2.csv', index=False)

# %%
correlation_matrix = df[numerical_columns].corr()
print(correlation_matrix)
Loan_Sanction_Amount_core = correlation_matrix['Loan Sanction Amount (USD)'].sort_values(ascending=False)
print(Loan_Sanction_Amount_core)
# Out:
#                                   Age  Income (USD)  \
# Age                          1.000000     -0.009392
# Income (USD)                -0.009392      1.000000
# Loan Amount Request (USD)   -0.010450      0.046155
# Current Loan Expenses (USD) -0.023616      0.050209
# Dependents                  -0.079574      0.004799
# Credit Score                 0.125900      0.011922
# No. of Defaults              0.003573     -0.001967
# Property ID                 -0.012358     -0.007493
# Property Age                -0.009718      0.999237
# Property Type                0.002196      0.008960
# Co-Applicant                 0.000632      0.000404
# Property Price              -0.009819      0.046484
# Loan Sanction Amount (USD)   0.011394      0.028552
#
#                              Loan Amount Request (USD)  \
# Age                                          -0.010450
# Income (USD)                                  0.046155
# Loan Amount Request (USD)                     1.000000
# Current Loan Expenses (USD)                   0.680450
# Dependents                                    0.039394
# Credit Score                                  0.173329
# No. of Defaults                               0.000088
# Property ID                                  -0.008426
# Property Age                                  0.045192
# Property Type                                 0.003802
# Co-Applicant                                  0.001864
# Property Price                                0.948350
# Loan Sanction Amount (USD)                    0.590483
#
#                              Current Loan Expenses (USD)  Dependents  \
# Age                                            -0.023616   -0.079574
# Income (USD)                                    0.050209    0.004799
# Loan Amount Request (USD)                       0.680450    0.039394
# Current Loan Expenses (USD)                     1.000000    0.043677
# Dependents                                      0.043677    1.000000
# Credit Score                                    0.111472   -0.083630
# No. of Defaults                                 0.002759    0.008420
# Property ID                                    -0.014477    0.001881
# Property Age                                    0.049486    0.004853
# Property Type                                   0.014771   -0.008387
# Co-Applicant                                    0.002124    0.003115
# Property Price                                  0.647159    0.035983
# Loan Sanction Amount (USD)                      0.400987    0.008855
#
#                              Credit Score  No. of Defaults  Property ID  \
# Age                              0.125900         0.003573    -0.012358
# Income (USD)                     0.011922        -0.001967    -0.007493
# Loan Amount Request (USD)        0.173329         0.000088    -0.008426
# Current Loan Expenses (USD)      0.111472         0.002759    -0.014477
# Dependents                      -0.083630         0.008420     0.001881
# Credit Score                     1.000000         0.006453    -0.005888
# No. of Defaults                  0.006453         1.000000    -0.001282
# Property ID                     -0.005888        -0.001282     1.000000
# Property Age                     0.011659        -0.002106    -0.007304
# Property Type                    0.008849         0.000477     0.008658
# Co-Applicant                     0.009203        -0.008191     0.008151
# Property Price                   0.166004         0.001718    -0.011890
# Loan Sanction Amount (USD)       0.345364        -0.008024    -0.013684
#
#                              Property Age  Property Type  Co-Applicant  \
# Age                             -0.009718       0.002196      0.000632
# Income (USD)                     0.999237       0.008960      0.000404
# Loan Amount Request (USD)        0.045192       0.003802      0.001864
# Current Loan Expenses (USD)      0.049486       0.014771      0.002124
# Dependents                       0.004853      -0.008387      0.003115
# Credit Score                     0.011659       0.008849      0.009203
# No. of Defaults                 -0.002106       0.000477     -0.008191
# Property ID                     -0.007304       0.008658      0.008151
# Property Age                     1.000000       0.008957      0.001090
# Property Type                    0.008957       1.000000     -0.001105
# Co-Applicant                     0.001090      -0.001105      1.000000
# Property Price                   0.045765       0.003279      0.005792
# Loan Sanction Amount (USD)       0.024805      -0.000002     -0.008368
#
#                              Property Price  Loan Sanction Amount (USD)
# Age                               -0.009819                    0.011394
# Income (USD)                       0.046484                    0.028552
# Loan Amount Request (USD)          0.948350                    0.590483
# Current Loan Expenses (USD)        0.647159                    0.400987
# Dependents                         0.035983                    0.008855
# Credit Score                       0.166004                    0.345364
# No. of Defaults                    0.001718                   -0.008024
# Property ID                       -0.011890                   -0.013684
# Property Age                       0.045765                    0.024805
# Property Type                      0.003279                   -0.000002
# Co-Applicant                       0.005792                   -0.008368
# Property Price                     1.000000                    0.553004
# Loan Sanction Amount (USD)         0.553004                    1.000000
# Loan Sanction Amount (USD)     1.000000
# Loan Amount Request (USD)      0.590483
# Property Price                 0.553004
# Current Loan Expenses (USD)    0.400987
# Credit Score                   0.345364
# Income (USD)                   0.028552
# Property Age                   0.024805
# Age                            0.011394
# Dependents                     0.008855
# Property Type                 -0.000002
# No. of Defaults               -0.008024
# Co-Applicant                  -0.008368
# Property ID                   -0.013684
# Name: Loan Sanction Amount (USD), dtype: float64

# %%
plt.hist(df['Loan Sanction Amount (USD)'])
# Out:
# (array([9774., 5219., 4565., 3295., 2499., 1742., 1261.,  827.,  491.,
#          327.]),
#  array([  -999.   ,  17510.005,  36019.01 ,  54528.015,  73037.02 ,
#          91546.025, 110055.03 , 128564.035, 147073.04 , 165582.045,
#         184091.05 ]),
#  <BarContainer object of 10 artists>)
